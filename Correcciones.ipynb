# %% [markdown]
# ## Correcciones de Examen 1
# Diego Dueñas Martín
# Exp 751426

# %% [markdown]
# ### 1- Dibuja un pipeline de un modelo de regresión lineal para un dataset que contiene factores numéricos de escalas diferentes, factores categóricos, datos sucios (faltantes, outliers), factores booleanos, y que se quiere hacer un cross-validation de train-test 70/30.
#
# ¿Cuál fue el error? Un pipeline mediocre que no cumplia con todos los requisitos pedidos en la pregunta.
#
# ¿Cuál es la corrección? Un pipeline un poco mas decente, que si engobla lo que si pide la pregunta.
#
# ¿Por qué se cometió el error? El error mas que nada radica, en que hice el pipeline, pero no sabia que era, solo trate de replicar una memoria sin entender un porque.
#
# ¿Cómo se puede evitar este error en el futuro? (Métodos prácticos aplicables. Nada de “estudiar más”)
# Buscando entender la logica y la razón de por que se realiza el EDA,la ingenieria de características, etc, y las relaciones de estos con el resultado, que es el modelo ajustado.

# %% [markdown]
# ![WhatsApp Image 2026-03-05 at 2.26.01 PM.jpeg](<attachment:WhatsApp Image 2026-03-05 at 2.26.01 PM.jpeg>)

# %% [markdown]
# ### 3. ¿Por qué se debe usar sólo el subset de training para ajustar un escalador?
# Porque a la hora de tu darle todos los datos a un modelo, ya no tiene nada que predecir, por que de cierta forma ya conoce todos los datos, por lo tanto si solo se usa el subset training se evita que el modelo ya conozca las respuestas de la pregunta que le vas a hacer, por asi decirlo.
#
# ¿Cuál fue el error? Una explicacin un poco desatinada.
#
# ¿Cuál es la corrección? Una explicación sin tantas palabras extras.
#
# ¿Por qué se cometió el error? Confusión de conceptos.
#
# ¿Cómo se puede evitar este error en el futuro? (Métodos prácticos aplicables. Nada de “estudiar más”)
# Aprendiendo las definiciones de forma simple, no siempre tiene que ser directamente del diccionario, en este caso podria ser que el training es el repaso del examen y el test es el examen, no te sirve de nada el examen si el repaso es lo mismo que el dicho.

# %% [markdown]
# ### 4. ¿Cuál es la diferencia entre penalizar con Ridge y penalizar con Lasso? ¿Qué se está haciendo con la penalización?
# En Ridge se penaliza agregandole la  sumatoria de los betas al cuadrado, y en Lasso se penaliza con los betas pero en absolutos, y en ridge esta penalizacion de Ridge hace que los betas se acerque a 0 (Tienen que ya estar estandarizados), y en Lasso convierte algunos coeficientes en 0.
#
# ¿Cuál fue el error? Principalmente se me olvido que hacian con los betas cada uno, y luego puse a medias tintas cual era el efecto de Lasso.
#
# ¿Cuál es la corrección? Una respuesta completa y apegada a los conceptos de Ridge y lasso.
#
# ¿Por qué se cometió el error? Nunca puse mucha atención al porque de y el que de los modelos penalizados, si sabia que eran pero no que hacian de manera exacta.
#
# ¿Cómo se puede evitar este error en el futuro? (Métodos prácticos aplicables. Nada de “estudiar más”)
# Una tablita comparativa estaria espectacular, por que los muestra lado a lado.

# %% [markdown]
# ### 5. Cuando se penaliza, ¿es importante escalar? ¿Por qué?
# Si, es de vital importancia, por que sino el mismo codigo te va a tronar, imaginate que estas trabajando con ridge y le haces los betas al cuadrado y de por si ya son grandes, significa una gran cantidad de trabajo extra lo que puede llevar a pantallazo azul.
#
# ¿Cuál fue el error? Explicacion breve y sin tanta referencia.
#
# ¿Cuál es la corrección? Una explicacion con ejemplo chido.
#
# ¿Por qué se cometió el error? Siento que no pude escribir bien la idea desde un inicio.
#
# ¿Cómo se puede evitar este error en el futuro? (Métodos prácticos aplicables. Nada de “estudiar más”)
# Teniendo en cuenta un ejemplo acertado, para así poder usarlo de referencia.

# %% [markdown]
# ### 7 Un trabajador en una línea de manufactura hace un cambio en el proceso y en la muestra que toma al día siguiente salen 15 segundos menos de lo usual. El tiempo promedio de inicio a fin de la línea era de 1800 segundos, con una desviación estándar de 20 segundos. Si se fuera a hacer el proceso de prueba de hipótesis, ¿cómo esperas que sea el valor del estadístico t? ¿Cómo esperas que sea el p-value? ¿Qué significaría?
# Ho: X=M
# Ha: X!=M
# Pues el valor del estadístico t depende mucho del tamaño de la muestra, si lo tomamos como de tamaño 25, por su formula (t = (x - M) / (desv / sqrt(n))), nos da -3.75, el p-value seria muy chico, lo suficiente para rechazar, la hipotesis nula, lo que significa que esa diferencia de 15 segundos si es visible.
#
# ¿Cuál fue el error?  No estadistico t y poca explicacion sobre que pasa con las hipotesis.
#
# ¿Cuál es la corrección?  Una explicacion más adecuada y completa, con la que explica que pasa con el p value y sus hipotesis.
#
# ¿Por qué se cometió el error? Prisas y falta de enfasis en los basicos, como la formula para el t estadistico.
#
# ¿Cómo se puede evitar este error en el futuro? (Métodos prácticos aplicables. Nada de “estudiar más”)
# Entender formulas y comprobarlas, es buena forma de aprenderlas.

# %% [markdown]
# ### 8 ¿Cuál es el punto de hacer cross-validation?
# Siempre existe el factor de la suerte, en este caso seria que el modelo le atina al resultado en el test, pero no lo predice, ahi es donde el cross-validation es importante, y lo que hace es comparar parametros sin tocar el test.
#
# ¿Cuál fue el error? hable de cosas como el sobre ajuste y no tenian nada relacionado con el tema.
#
# ¿Cuál es la corrección? Explicacion que si tiene relacion con e concepto.
#
# ¿Por qué se cometió el error? Falta de atencion y confusión.
#
# ¿Cómo se puede evitar este error en el futuro? (Métodos prácticos aplicables. Nada de “estudiar más”)
# Memorizar un dibujo que represente el cross validation, ya que es mas facil aprenderse una imagen a que una definicion.

# %% [markdown]
# ### 9 Describe los pasos que seguirías al hacer un análisis exploratorio de datos. Justifica cada paso.
# 1- Entender el problema y los datos antes de tocarlos: si no sabes donde empiezas, no sabes donde terminas.
# 2- Estructura básica: Entender como esta formado da una idea clara hacia el futuro.
# 3- Análisis de valores faltantes: Que hay en cada columna determina que procesos vamos a tomar.
# 4- Determinar Media, mediana, desviación, min, max, percentiles para numéricas: es un paso básico pero imprescindible, ya que esa es la base de la resolución.
# 5- Detectar los outliers: los valores mas extremos o son un erro o son unos de los datos mas importantes.
# 6- Analisis de correlación: determinar como estan relacionadas las variables ayuda a determinar que es util y que no.
# 7- hacer plan de resolucion del problema: no te sirve de nada si no piensas en como resolverlo.
#
# ¿Cuál fue el error? Me falto hacer mención de outliers, las medias, modas y medianas, analisis de correlacion.
# ¿Cuál es la corrección? Mención de outliers, las medias, modas y medianas, analisis de correlacion.
# ¿Por qué se cometió el error? Falto vision de min parte.
# ¿Cómo se puede evitar este error en el futuro? (Métodos prácticos aplicables. Nada de “estudiar más”)
# Hacer que sea regla este procedimiento para resolver problemas, y asi acostumbrarse.

# %% [markdown]
# ### 10 Imagina un modelo de regresión lineal simple de dos factores. Añade una interacción entre esos dos factores. ¿Cómo afecta el incremento de un factor al beta del otro?
# y= B0 + B1X1 + B2X2 + B3(X1*X2), pues es como pnsarlo de la siguiente manera sin interacción, untarle mantequilla al pan siempre añade las mismas calorías, sin importar qué tipo de pan sea. Con interacción, cuánto engordan esas calorías de mantequilla depende de si el pan es normal o integral.
#
# ¿Cuál fue el error?  me falto añadir interaccion.
#
# ¿Cuál es la corrección?  Una interracion y la explicacion con una metafora.
#
# ¿Por qué se cometió el error? Se me olvido  la formula.
#
# ¿Cómo se puede evitar este error en el futuro? (Métodos prácticos aplicables. Nada de “estudiar más”)
# Pues ya se va a evitar, por que la metafora ayufa con una visualizacion del porque, y no estaba tan dificil la misma.
