# %% [markdown]
# # Laboratorio de regresión - 4

# %% [markdown]
# |                |   |
# :----------------|---|
# | **Nombre**     |  Diego Dueñas Martín |
# | **Fecha**      |  08/02/2026 |
# | **Expediente** |  751426 |

# %% [markdown]
# ## Modelos penalizados

# %% [markdown]
# Hasta ahora la función de costo que usamos para decidir qué tan bueno es nuestro modelo al momento de ajustar es:
#
# $$ \text{RSS} = \sum_{i=1}^n e_i^2 = \sum_{i=1}^n (y_i - \hat{y_i})^2 $$

# %% [markdown]
# Dado que los errores obtenidos son una combinación de sesgo y varianza, puede ser que se sesgue un parámetro para minimizar el error. Esto significa que el modelo puede decidir que la salida no sea una combinación de los factores, sino una fuerte predilección sobre uno de los factores solamente.

# %% [markdown]
# E.g. se quiere ajustar un modelo
#
# $$ \hat{z} = \hat{\beta_0} + \hat{\beta_1} x + \hat{\beta_2} y $$

# %% [markdown]
# Se ajusta el modelo y se decide que la mejor decisión es $\hat{\beta_1} = 10000$ y $\hat{\beta_2}=50$. Considera limitaciones de problemas reales:
# - Quizás los parámetros son ajustes de maquinaria que se deben realizar para conseguir el mejor producto posible, y que $10000$ sea imposible de asignar.
# - Quizás los datos actuales están sesgados y sólo hacen parecer que uno de los factores importa más que el otro.

# %% [markdown]
# Una de las formas en las que se puede mitigar este problema es penalizando a los parámetros del modelo, cambiando la función de costo:

# %% [markdown]
# $$ \text{RSS}_{L2} = \sum_{i=1}^n e_i^2  + \lambda \sum_{j=1}^p \hat{\beta_j}^2 $$

# %% [markdown]
# El *L2* significa que se está agregando una penalización de segundo orden. Lo que hace esta penalización es que los factores ahora sólo tendrán permitido crecer si hay una reducción al menos proporcional en el error (sacrificamos sesgo, pero reducimos la varianza).

# %% [markdown]
# Asimismo, existe la penalización *L1*

# %% [markdown]
# $$ \text{RSS}_{L1} = \sum_{i=1}^n e_i^2  + \lambda \sum_{j=1}^p |\hat{\beta_j}| $$

# %% [markdown]
# A las penalizaciones *L2* y *L1* se les conoce también como Ridge y Lasso, respectivamente.

# %% [markdown]
# Para realizar una regresión con penalización de Ridge o de Lasso usamos el objeto `Ridge(alpha=?)` o `Lasso(alpha=?)` en lugar de `LinearRegression()` de `sklearn`.

# %% [markdown]
# Utiliza el dataset de publicidad (Advertising.csv) y realiza 3 regresiones múltiples:
#
# $$ \text{sales} = \beta_0 + \beta_1 (\text{TV}) + \beta_2 (\text{radio}) + \beta_3 (\text{newspaper}) + \epsilon $$

# %% [markdown]
# 1. Sin penalización
# 2. Con penalización L2
# 3. Con penalización L1
#
# ¿Qué puedes observar al ajustar los valores de `alpha`?
#
# Compara los resultados de los coeficientes utilizando valores diferentes de $\alpha$ y los $R^2$ resultantes.

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# dataset
df = pd.read_csv('Advertising.csv')

# Definir variables
X = df[['TV', 'radio', 'newspaper']] # independientes
y = df['sales'] # dependiente

# Separar datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# 1. Regresión sin penalización
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
print("Linear Regression (sin penalización):")
print("Coeficientes:", lr.coef_)
print("R^2:", r2_score(y_test, y_pred_lr))
# Out:
# Linear Regression (sin penalización):
# Coeficientes: [0.04543356 0.19145654 0.00256809]
# R^2: 0.8935163320163658

# %%
# 2. Regresión Ridge (L2)
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)
y_pred_ridge = ridge.predict(X_test)
print("\nRidge Regression (L2, alpha=1.0):")
print("Coeficientes:", ridge.coef_)
print("R^2:", r2_score(y_test, y_pred_ridge))
# Out:
# Ridge Regression (L2, alpha=1.0):
# Coeficientes: [0.04543356 0.19144979 0.0025699 ]
# R^2: 0.8935173307476478

# %%
# 3. Regresión Lasso (L1)
lasso = Lasso(alpha=1.0)
lasso.fit(X_train, y_train)
y_pred_lasso = lasso.predict(X_test)
print("\nLasso Regression (L1, alpha=1.0):")
print("Coeficientes:", lasso.coef_)
print("R^2:", r2_score(y_test, y_pred_lasso))
# Out:
# Lasso Regression (L1, alpha=1.0):
# Coeficientes: [0.04532839 0.18763702 0.0012818 ]
# R^2: 0.8951947205229303

# %%
#diferentes valores de alpha
for a in [0.1, 1, 10]:
    ridge = Ridge(alpha=a)
    ridge.fit(X_train, y_train)
    print(f"\nRidge alpha={a} coeficientes:", ridge.coef_, "R^2:", ridge.score(X_test, y_test))
    lasso = Lasso(alpha=a)
    lasso.fit(X_train, y_train)
    print(f"Lasso alpha={a} coeficientes:", lasso.coef_, "R^2:", lasso.score(X_test, y_test))
# Out:
# Ridge alpha=0.1 coeficientes: [0.04543356 0.19145586 0.00256827] R^2: 0.8935164319222046
# Lasso alpha=0.1 coeficientes: [0.04542302 0.19107496 0.00243936] R^2: 0.8937022132677509
#
# Ridge alpha=1 coeficientes: [0.04543356 0.19144979 0.0025699 ] R^2: 0.8935173307476478
# Lasso alpha=1 coeficientes: [0.04532839 0.18763702 0.0012818 ] R^2: 0.8951947205229303
#
# Ridge alpha=10 coeficientes: [0.04543358 0.19138909 0.00258621] R^2: 0.8935262866430345
# Lasso alpha=10 coeficientes: [0.04438442 0.14777315 0.        ] R^2: 0.8909156449341449
